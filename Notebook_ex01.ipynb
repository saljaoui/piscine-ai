# %%
import pandas as pd

dates = pd.date_range("2010-01-01", "2020-12-31")
integer_series = pd.Series(range(len(dates)), index=dates, name="integer_series")
integer_series
# Out:
# 2010-01-01       0
# 2010-01-02       1
# 2010-01-03       2
# 2010-01-04       3
# 2010-01-05       4
#               ...
# 2020-12-27    4013
# 2020-12-28    4014
# 2020-12-29    4015
# 2020-12-30    4016
# 2020-12-31    4017
# Freq: D, Name: integer_series, Length: 4018, dtype: int64

# %%
integer_series.rolling(7).mean()
# Out:
# 2010-01-01       NaN
# 2010-01-02       NaN
# 2010-01-03       NaN
# 2010-01-04       NaN
# 2010-01-05       NaN
#                ...
# 2020-12-27    4010.0
# 2020-12-28    4011.0
# 2020-12-29    4012.0
# 2020-12-30    4013.0
# 2020-12-31    4014.0
# Freq: D, Name: integer_series, Length: 4018, dtype: float64
