# %%
import spacy

nlp = spacy.load("en_core_web_sm")

doc = nlp("car")
v = doc[0].vector

print("Shape:", v.shape)
print("Sum:", v[:20].sum().as_integer_ratio())
# Out:
# Shape: (96,)
# Sum: (12494889, 4194304)
