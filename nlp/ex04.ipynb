# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords

nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to /home/saljaoui/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/saljaoui/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
text = """
The goal of this exercise is to learn to remove stop words with NLTK.  
Stop words usually refers to the most common words in a language.
"""

words = word_tokenize(text)

stop_words = set(stopwords.words('english'))
# print(stop_words)
# print(words)

filtered_words = []

for w in words:
    if w not in stop_words:
        filtered_words.append(w)

print(filtered_words)
# Out:
# ['The', 'goal', 'exercise', 'learn', 'remove', 'stop', 'words', 'NLTK', '.', 'Stop', 'words', 'usually', 'refers', 'common', 'words', 'language', '.']
