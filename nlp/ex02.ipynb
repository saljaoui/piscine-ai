# %%
import string

text = 'Remove, this from .? the sentence !!!! !"#&\'()*+,-./:;<=>_'
translator = str.maketrans('', '', string.punctuation)
soufian = text.translate(translator)

# print(string.punctuation)
# print(text)
# print(type(text))
# print(type(translator))


print(soufian)
# Out:
# Remove this from  the sentence
