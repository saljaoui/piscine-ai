# %%
import pandas as pd

list = ["This is my first NLP exercise", "wtf!!!!!"]
series_data = pd.Series(list, name='text')

# %%
series_data.str.lower()
# Out:
# 0    this is my first nlp exercise
# 1                         wtf!!!!!
# Name: text, dtype: object

# %%
series_data.str.upper()
# Out:
# 0    THIS IS MY FIRST NLP EXERCISE
# 1                         WTF!!!!!
# Name: text, dtype: object
