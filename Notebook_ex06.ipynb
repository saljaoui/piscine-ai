# %%
import pandas as pd
import numpy as np

business_dates = pd.bdate_range('2021-01-01', '2021-12-31')

tickers = ['AAPL', 'FB', 'GE', 'AMZN', 'DAI']

index = pd.MultiIndex.from_product([business_dates, tickers], names=['Date', 'Ticker'])

market_data = pd.DataFrame(index=index,
                        data=np.random.randn(len(index), 1),
                        columns=['Prediction'])

# market_data.groupby('Ticker').get_group('AAPL')
unstacked = market_data.unstack('Ticker')

unstacked.head(3)
# Out:
#            Prediction
# Ticker           AAPL      AMZN       DAI        FB        GE
# Date
# 2021-01-01   0.000234 -0.067069  0.071988 -0.785976  0.974747
# 2021-01-04  -1.328267  0.454897  1.142261 -0.082117  0.043653
# 2021-01-05   0.023032 -0.954945  0.894335 -0.708099 -1.457686

# %%
ax = unstacked.plot(title="Stocks 2021")
ax.set_ylabel("Prediction")
# Out:
# Text(0, 0.5, 'Prediction')
