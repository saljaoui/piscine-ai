# %%
import numpy as np
from sklearn.datasets import fetch_california_housing
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV

# data (NO train_test_split here, GridSearchCV will do the split via cv)
housing = fetch_california_housing()
X, y = housing["data"], housing["target"]

parameters = { "n_estimators": [10, 50, 75],
            "max_depth": [3, 5, 7],
            "min_samples_leaf": [10, 20, 30]}

rf = RandomForestRegressor(random_state=43)

gridsearch = GridSearchCV(
    estimator=rf,
    param_grid=parameters,
    cv=[(np.arange(18576), np.arange(18576, 20640))],
    n_jobs=-1
)

gridsearch.fit(X, y)

def select_model_verbose(gs):
    return gs.best_estimator_, gs.best_params_, gs.best_score_

import numpy as np

new_point = np.array([[3.2031, 52., 5.47761194, 1.07960199,
                       910., 2.26368159, 37.85, -122.26]])

model, best_params, best_score = select_model_verbose(gridsearch)

pred = model.predict(new_point)
print("Best params:", best_params)
print("Best score :", best_score)
print("Prediction :", pred)
# Out:
# Best params: {'max_depth': 7, 'min_samples_leaf': 10, 'n_estimators': 75}
# Best score : 0.6273114659038119
# Prediction : [2.65618579]
